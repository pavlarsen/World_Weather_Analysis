# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size = 2000)
lngs = np.random.uniform(-180,180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config2 import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asau
# Processing Record 2 of Set 1 | kangaatsiaq
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | ivanava
# Processing Record 8 of Set 1 | kavaratti
# Processing Record 9 of Set 1 | alofi
# Processing Record 10 of Set 1 | morondava
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | clyde river
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | surt
# Processing Record 17 of Set 1 | goya
# Processing Record 18 of Set 1 | zlatoust
# Processing Record 19 of Set 1 | sorong
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | sindou
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | vestmannaeyjar
# Processing Record 25 of Set 1 | neryungri
# Processing Record 26 of Set 1 | naze
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | vardo
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | madison
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | kollam
# Processing Record 34 of Set 1 | marabba
# Processing Record 35 of Set 1 | buraydah
# Processing Record 36 of Set 1 | westport
# Processing Record 37 of Set 1 | faya
# Processing Record 38 of Set 1 | goksun
# Processing Record 39 of Set 1 | jermuk
# Processing Record 40 of Set 1 | voyvozh
# Processing Record 41 of Set 1 | henties bay
# Processing Record 42 of Set 1 | mojoagung
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | kholm
# Processing Record 46 of Set 1 | ust-kuyga
# Processing Record 47 of Set 1 | nelson bay
# Processing Record 48 of Set 1 | mayo
# Processing Record 49 of Set 1 | plessisville
# Processing Record 50 of Set 1 | licata
# Processing Record 1 of Set 2 | de pere
# Processing Record 2 of Set 2 | yambio
# Processing Record 3 of Set 2 | muroto
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | port lincoln
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | sao gabriel da cachoeira
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | camopi
# Processing Record 12 of Set 2 | smoky lake
# Processing Record 13 of Set 2 | ketchikan
# Processing Record 14 of Set 2 | linjiang
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | fosses
# Processing Record 19 of Set 2 | touros
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | san rafael del sur
# Processing Record 22 of Set 2 | taltal
# Processing Record 23 of Set 2 | hobyo
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | buta
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | goderich
# Processing Record 30 of Set 2 | isilkul
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | winsum
# Processing Record 33 of Set 2 | kaka
# Processing Record 34 of Set 2 | abha
# Processing Record 35 of Set 2 | lago da pedra
# Processing Record 36 of Set 2 | egvekinot
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | iralaya
# Processing Record 39 of Set 2 | massaguet
# Processing Record 40 of Set 2 | praia
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 2 | shuya
# Processing Record 44 of Set 2 | dvinskoy
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | subaan
# Processing Record 48 of Set 2 | yulara
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | deputatskiy
# Processing Record 2 of Set 3 | klyuchi
# Processing Record 3 of Set 3 | solton
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | biharamulo
# Processing Record 6 of Set 3 | katangli
# Processing Record 7 of Set 3 | manggar
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 3 | manono
# Processing Record 11 of Set 3 | salalah
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | staryy nadym
# Processing Record 14 of Set 3 | ponta do sol
# Processing Record 15 of Set 3 | san cristobal
# Processing Record 16 of Set 3 | zhanaozen
# Processing Record 17 of Set 3 | almaznyy
# Processing Record 18 of Set 3 | antalaha
# Processing Record 19 of Set 3 | casablanca
# Processing Record 20 of Set 3 | mae ramat
# Processing Record 21 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | gunjur
# Processing Record 27 of Set 3 | rundu
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | esil
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | kaoma
# Processing Record 32 of Set 3 | ulaangom
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | sao joao da barra
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | aksu
# Processing Record 37 of Set 3 | marondera
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | san carlos de bariloche
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | flinders
# Processing Record 43 of Set 3 | wilmington
# Processing Record 44 of Set 3 | tsiroanomandidy
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 3 | bintulu
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | temir
# Processing Record 1 of Set 4 | bethel
# Processing Record 2 of Set 4 | sorland
# Processing Record 3 of Set 4 | vanimo
# Processing Record 4 of Set 4 | nikolskoye
# Processing Record 5 of Set 4 | mogadishu
# Processing Record 6 of Set 4 | kudahuvadhoo
# Processing Record 7 of Set 4 | civita castellana
# Processing Record 8 of Set 4 | hazorasp
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | orlik
# Processing Record 12 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 4 | sao jose da coroa grande
# Processing Record 14 of Set 4 | balsas
# Processing Record 15 of Set 4 | banda
# Processing Record 16 of Set 4 | mercedes
# Processing Record 17 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 4 | kozhva
# Processing Record 19 of Set 4 | luau
# Processing Record 20 of Set 4 | sola
# Processing Record 21 of Set 4 | cayenne
# Processing Record 22 of Set 4 | cap malheureux
# Processing Record 23 of Set 4 | fort nelson
# Processing Record 24 of Set 4 | nemuro
# Processing Record 25 of Set 4 | sao felix do xingu
# Processing Record 26 of Set 4 | cairns
# Processing Record 27 of Set 4 | sabang
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | dingle
# Processing Record 30 of Set 4 | igarka
# Processing Record 31 of Set 4 | kyra
# Processing Record 32 of Set 4 | saravan
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 4 | pachino
# Processing Record 36 of Set 4 | manakara
# Processing Record 37 of Set 4 | carrickmacross
# Processing Record 38 of Set 4 | charters towers
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | dunedin
# Processing Record 41 of Set 4 | gat
# Processing Record 42 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | codrington
# Processing Record 44 of Set 4 | krasnodon
# Processing Record 45 of Set 4 | chokurdakh
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | new norfolk
# Processing Record 48 of Set 4 | meadow lake
# Processing Record 49 of Set 4 | pervouralsk
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | nizhniy tsasuchey
# Processing Record 2 of Set 5 | akranes
# Processing Record 3 of Set 5 | araguaina
# Processing Record 4 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | kempsey
# Processing Record 7 of Set 5 | camacha
# Processing Record 8 of Set 5 | gerash
# Processing Record 9 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | khatanga
# Processing Record 12 of Set 5 | likoporia
# City not found. Skipping...
# Processing Record 13 of Set 5 | agbor
# Processing Record 14 of Set 5 | matara
# Processing Record 15 of Set 5 | tazovskiy
# Processing Record 16 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | brae
# Processing Record 19 of Set 5 | the valley
# Processing Record 20 of Set 5 | dudinka
# Processing Record 21 of Set 5 | svetlyy
# Processing Record 22 of Set 5 | chuy
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | yauya
# Processing Record 25 of Set 5 | nizwa
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | khandbari
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | thompson
# Processing Record 30 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 5 | warrington
# Processing Record 32 of Set 5 | victor harbor
# Processing Record 33 of Set 5 | vestmanna
# Processing Record 34 of Set 5 | douentza
# Processing Record 35 of Set 5 | ventspils
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | qaanaaq
# Processing Record 38 of Set 5 | khor
# Processing Record 39 of Set 5 | kieta
# Processing Record 40 of Set 5 | yima
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | mount isa
# Processing Record 43 of Set 5 | safford
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | prince george
# Processing Record 46 of Set 5 | rantepao
# Processing Record 47 of Set 5 | ust-omchug
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | grindavik
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | palasa
# Processing Record 2 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | adrar
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | camara de lobos
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | katherine
# Processing Record 9 of Set 6 | dali
# Processing Record 10 of Set 6 | kargasok
# Processing Record 11 of Set 6 | sinnamary
# Processing Record 12 of Set 6 | yar-sale
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | umm kaddadah
# Processing Record 15 of Set 6 | pandamatenga
# Processing Record 16 of Set 6 | palu
# Processing Record 17 of Set 6 | shadegan
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | blagoyevo
# Processing Record 20 of Set 6 | georgiyevka
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | serowe
# Processing Record 24 of Set 6 | kenora
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | kushikino
# Processing Record 27 of Set 6 | nara
# Processing Record 28 of Set 6 | luderitz
# Processing Record 29 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 6 | palembang
# Processing Record 31 of Set 6 | raichur
# Processing Record 32 of Set 6 | zharkent
# Processing Record 33 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 6 | mascote
# Processing Record 35 of Set 6 | bow island
# Processing Record 36 of Set 6 | rocha
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | norfolk
# Processing Record 40 of Set 6 | broome
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 6 | seoul
# Processing Record 44 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 45 of Set 6 | katobu
# Processing Record 46 of Set 6 | burns lake
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | lavrentiya
# Processing Record 49 of Set 6 | muros
# Processing Record 50 of Set 6 | olinda
# Processing Record 1 of Set 7 | aquiraz
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | bud
# Processing Record 4 of Set 7 | mount vernon
# Processing Record 5 of Set 7 | norsup
# Processing Record 6 of Set 7 | luanda
# Processing Record 7 of Set 7 | havre-saint-pierre
# Processing Record 8 of Set 7 | lebu
# Processing Record 9 of Set 7 | jawhar
# Processing Record 10 of Set 7 | pangkalanbuun
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | ambilobe
# Processing Record 14 of Set 7 | hovd
# Processing Record 15 of Set 7 | svetla nad sazavou
# Processing Record 16 of Set 7 | araouane
# Processing Record 17 of Set 7 | marsa matruh
# Processing Record 18 of Set 7 | severo-kurilsk
# Processing Record 19 of Set 7 | dir
# Processing Record 20 of Set 7 | warner robins
# Processing Record 21 of Set 7 | leh
# Processing Record 22 of Set 7 | minab
# Processing Record 23 of Set 7 | verkhniy lomov
# Processing Record 24 of Set 7 | shelburne
# Processing Record 25 of Set 7 | tual
# Processing Record 26 of Set 7 | urucara
# Processing Record 27 of Set 7 | arman
# Processing Record 28 of Set 7 | atherton
# Processing Record 29 of Set 7 | nome
# Processing Record 30 of Set 7 | yumbing
# Processing Record 31 of Set 7 | ipixuna
# Processing Record 32 of Set 7 | maceio
# Processing Record 33 of Set 7 | dzilam gonzalez
# Processing Record 34 of Set 7 | priiskovyy
# Processing Record 35 of Set 7 | pundaguitan
# Processing Record 36 of Set 7 | nuuk
# Processing Record 37 of Set 7 | atambua
# Processing Record 38 of Set 7 | nanortalik
# Processing Record 39 of Set 7 | krasnoborsk
# Processing Record 40 of Set 7 | arraial do cabo
# Processing Record 41 of Set 7 | balkanabat
# Processing Record 42 of Set 7 | mezen
# Processing Record 43 of Set 7 | okhotsk
# Processing Record 44 of Set 7 | montecristi
# Processing Record 45 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 7 | lethem
# Processing Record 47 of Set 7 | tiksi
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | acucena
# Processing Record 50 of Set 7 | saint-joseph
# Processing Record 1 of Set 8 | modrica
# Processing Record 2 of Set 8 | alice springs
# Processing Record 3 of Set 8 | carlsbad
# Processing Record 4 of Set 8 | abonnema
# Processing Record 5 of Set 8 | aguada de cima
# Processing Record 6 of Set 8 | chandler
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | ahipara
# Processing Record 9 of Set 8 | boa vista
# Processing Record 10 of Set 8 | havoysund
# Processing Record 11 of Set 8 | porto novo
# Processing Record 12 of Set 8 | yumen
# Processing Record 13 of Set 8 | masuguru
# Processing Record 14 of Set 8 | sai buri
# Processing Record 15 of Set 8 | harwich
# Processing Record 16 of Set 8 | awbari
# Processing Record 17 of Set 8 | lao cai
# Processing Record 18 of Set 8 | hammerfest
# Processing Record 19 of Set 8 | port keats
# Processing Record 20 of Set 8 | souillac
# Processing Record 21 of Set 8 | houma
# Processing Record 22 of Set 8 | iracoubo
# Processing Record 23 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 8 | mahibadhoo
# Processing Record 25 of Set 8 | lencois paulista
# Processing Record 26 of Set 8 | burica
# City not found. Skipping...
# Processing Record 27 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 8 | omboue
# Processing Record 29 of Set 8 | fukue
# Processing Record 30 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 8 | parrita
# Processing Record 32 of Set 8 | midland
# Processing Record 33 of Set 8 | lasa
# Processing Record 34 of Set 8 | jagalur
# Processing Record 35 of Set 8 | talnakh
# Processing Record 36 of Set 8 | keshan
# City not found. Skipping...
# Processing Record 37 of Set 8 | kokkola
# Processing Record 38 of Set 8 | sterling
# Processing Record 39 of Set 8 | soe
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 8 | litovko
# Processing Record 43 of Set 8 | labuhan
# Processing Record 44 of Set 8 | zugdidi
# Processing Record 45 of Set 8 | taber
# Processing Record 46 of Set 8 | hami
# Processing Record 47 of Set 8 | kunashak
# Processing Record 48 of Set 8 | dongsheng
# Processing Record 49 of Set 8 | antsohihy
# Processing Record 50 of Set 8 | porbandar
# Processing Record 1 of Set 9 | nishihara
# Processing Record 2 of Set 9 | oussouye
# Processing Record 3 of Set 9 | socorro
# Processing Record 4 of Set 9 | okoneshnikovo
# Processing Record 5 of Set 9 | lagoa
# Processing Record 6 of Set 9 | basco
# Processing Record 7 of Set 9 | russell
# Processing Record 8 of Set 9 | atar
# Processing Record 9 of Set 9 | flin flon
# Processing Record 10 of Set 9 | karratha
# Processing Record 11 of Set 9 | honiara
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | kimbe
# Processing Record 14 of Set 9 | takaka
# Processing Record 15 of Set 9 | voh
# Processing Record 16 of Set 9 | dhidhdhoo
# Processing Record 17 of Set 9 | krasnoselkup
# Processing Record 18 of Set 9 | kilindoni
# Processing Record 19 of Set 9 | saldanha
# Processing Record 20 of Set 9 | bendigo
# Processing Record 21 of Set 9 | ust-maya
# Processing Record 22 of Set 9 | te anau
# Processing Record 23 of Set 9 | anchorage
# Processing Record 24 of Set 9 | half moon bay
# Processing Record 25 of Set 9 | aripuana
# Processing Record 26 of Set 9 | calvinia
# Processing Record 27 of Set 9 | suntar
# Processing Record 28 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 9 | mangrol
# Processing Record 30 of Set 9 | hirado
# Processing Record 31 of Set 9 | jingdezhen
# Processing Record 32 of Set 9 | carnduff
# Processing Record 33 of Set 9 | corinto
# Processing Record 34 of Set 9 | garden city
# Processing Record 35 of Set 9 | namibe
# Processing Record 36 of Set 9 | constitucion
# Processing Record 37 of Set 9 | barcelos
# Processing Record 38 of Set 9 | roald
# Processing Record 39 of Set 9 | goma
# Processing Record 40 of Set 9 | luwuk
# Processing Record 41 of Set 9 | champerico
# Processing Record 42 of Set 9 | nouakchott
# Processing Record 43 of Set 9 | ulladulla
# Processing Record 44 of Set 9 | manokwari
# Processing Record 45 of Set 9 | pahrump
# Processing Record 46 of Set 9 | shaunavon
# Processing Record 47 of Set 9 | alugan
# Processing Record 48 of Set 9 | tanout
# Processing Record 49 of Set 9 | victoria
# Processing Record 50 of Set 9 | hyeres
# Processing Record 1 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 10 | datong
# Processing Record 3 of Set 10 | labranzagrande
# Processing Record 4 of Set 10 | oktyabrskoye
# Processing Record 5 of Set 10 | cao bang
# Processing Record 6 of Set 10 | uong bi
# Processing Record 7 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | fairbanks
# Processing Record 9 of Set 10 | mehamn
# Processing Record 10 of Set 10 | shumskiy
# Processing Record 11 of Set 10 | putina
# Processing Record 12 of Set 10 | coihueco
# Processing Record 13 of Set 10 | swan hill
# Processing Record 14 of Set 10 | debre tabor
# Processing Record 15 of Set 10 | xining
# Processing Record 16 of Set 10 | lucea
# Processing Record 17 of Set 10 | boca do acre
# Processing Record 18 of Set 10 | maldonado
# Processing Record 19 of Set 10 | hermiston
# Processing Record 20 of Set 10 | quatre cocos
# Processing Record 21 of Set 10 | eskil
# Processing Record 22 of Set 10 | maniitsoq
# Processing Record 23 of Set 10 | port-gentil
# Processing Record 24 of Set 10 | chegdomyn
# Processing Record 25 of Set 10 | syracuse
# Processing Record 26 of Set 10 | bandar-e lengeh
# Processing Record 27 of Set 10 | valdepenas
# Processing Record 28 of Set 10 | akureyri
# Processing Record 29 of Set 10 | shieli
# Processing Record 30 of Set 10 | warrnambool
# Processing Record 31 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 10 | kati
# Processing Record 33 of Set 10 | hervey bay
# Processing Record 34 of Set 10 | severnyy
# Processing Record 35 of Set 10 | yongan
# Processing Record 36 of Set 10 | ahuimanu
# Processing Record 37 of Set 10 | xuanzhou
# Processing Record 38 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 10 | pangody
# Processing Record 40 of Set 10 | huercal-overa
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | atka
# City not found. Skipping...
# Processing Record 43 of Set 10 | hit
# Processing Record 44 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 10 | comodoro rivadavia
# Processing Record 46 of Set 10 | semey
# Processing Record 47 of Set 10 | vanavara
# Processing Record 48 of Set 10 | tignere
# Processing Record 49 of Set 10 | salamiyah
# Processing Record 50 of Set 10 | arona
# Processing Record 1 of Set 11 | tooele
# Processing Record 2 of Set 11 | fort-shevchenko
# Processing Record 3 of Set 11 | udachnyy
# Processing Record 4 of Set 11 | rudnyy
# Processing Record 5 of Set 11 | paragominas
# Processing Record 6 of Set 11 | uchiza
# Processing Record 7 of Set 11 | saint-augustin
# Processing Record 8 of Set 11 | massakory
# Processing Record 9 of Set 11 | cidreira
# Processing Record 10 of Set 11 | port blair
# Processing Record 11 of Set 11 | kemi
# Processing Record 12 of Set 11 | traverse city
# Processing Record 13 of Set 11 | pemangkat
# Processing Record 14 of Set 11 | plettenberg bay
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | wucheng
# Processing Record 17 of Set 11 | lufilufi
# Processing Record 18 of Set 11 | uruzgan
# Processing Record 19 of Set 11 | torrington
# Processing Record 20 of Set 11 | kayerkan
# Processing Record 21 of Set 11 | khorixas
# Processing Record 22 of Set 11 | mananjary
# Processing Record 23 of Set 11 | berdigestyakh
# Processing Record 24 of Set 11 | raudeberg
# Processing Record 25 of Set 11 | atok
# Processing Record 26 of Set 11 | turukhansk
# Processing Record 27 of Set 11 | baykalovo
# Processing Record 28 of Set 11 | san andres
# Processing Record 29 of Set 11 | acarau
# Processing Record 30 of Set 11 | asosa
# Processing Record 31 of Set 11 | nouadhibou
# Processing Record 32 of Set 11 | copalillo
# Processing Record 33 of Set 11 | valle de allende
# Processing Record 34 of Set 11 | khandyga
# Processing Record 35 of Set 11 | zarubino
# Processing Record 36 of Set 11 | navahrudak
# Processing Record 37 of Set 11 | necochea
# Processing Record 38 of Set 11 | el carmen
# Processing Record 39 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 11 | sibolga
# Processing Record 41 of Set 11 | north bend
# Processing Record 42 of Set 11 | nampula
# Processing Record 43 of Set 11 | acapulco
# Processing Record 44 of Set 11 | kampot
# Processing Record 45 of Set 11 | guarapari
# Processing Record 46 of Set 11 | palmer
# Processing Record 47 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 11 | saint-pierre
# Processing Record 49 of Set 11 | valdivia
# Processing Record 50 of Set 11 | poum
# Processing Record 1 of Set 12 | manavgat
# Processing Record 2 of Set 12 | clarence town
# Processing Record 3 of Set 12 | malakal
# Processing Record 4 of Set 12 | tombouctou
# Processing Record 5 of Set 12 | ngunguru
# Processing Record 6 of Set 12 | bakchar
# Processing Record 7 of Set 12 | peniche
# Processing Record 8 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 12 | gazanjyk
# Processing Record 10 of Set 12 | erenhot
# Processing Record 11 of Set 12 | laguna
# Processing Record 12 of Set 12 | businga
# Processing Record 13 of Set 12 | fare
# Processing Record 14 of Set 12 | tabuk
# Processing Record 15 of Set 12 | arlit
# Processing Record 16 of Set 12 | jizan
# Processing Record 17 of Set 12 | hukuntsi
# Processing Record 18 of Set 12 | inhambane
# Processing Record 19 of Set 12 | wenling
# Processing Record 20 of Set 12 | bongandanga
# Processing Record 21 of Set 12 | puerto guzman
# Processing Record 22 of Set 12 | genhe
# Processing Record 23 of Set 12 | gizycko
# Processing Record 24 of Set 12 | kunda
# Processing Record 25 of Set 12 | cockburn town
# Processing Record 26 of Set 12 | cubuk
# Processing Record 27 of Set 12 | ayan
# Processing Record 28 of Set 12 | tucuman
# Processing Record 29 of Set 12 | ambulu
# Processing Record 30 of Set 12 | kijang
# Processing Record 31 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 12 | grand forks
# Processing Record 34 of Set 12 | engenheiro beltrao
# Processing Record 35 of Set 12 | bindi
# Processing Record 36 of Set 12 | kununurra
# Processing Record 37 of Set 12 | luziania
# Processing Record 38 of Set 12 | namatanai
# Processing Record 39 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 12 | the woodlands
# Processing Record 41 of Set 12 | burnie
# Processing Record 42 of Set 12 | san jose
# Processing Record 43 of Set 12 | college
# Processing Record 44 of Set 12 | harper
# Processing Record 45 of Set 12 | chinchani
# Processing Record 46 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 47 of Set 12 | santa isabel do rio negro
# Processing Record 48 of Set 12 | namwala
# Processing Record 49 of Set 12 | maslovka
# Processing Record 50 of Set 12 | takoradi
# Processing Record 1 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 2 of Set 13 | talikota
# Processing Record 3 of Set 13 | coihaique
# Processing Record 4 of Set 13 | puerto colombia
# Processing Record 5 of Set 13 | lompoc
# Processing Record 6 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 13 | palana
# Processing Record 8 of Set 13 | tamiahua
# Processing Record 9 of Set 13 | yangambi
# Processing Record 10 of Set 13 | novonukutskiy
# Processing Record 11 of Set 13 | lakes entrance
# Processing Record 12 of Set 13 | ostrovnoy
# Processing Record 13 of Set 13 | hudson bay
# Processing Record 14 of Set 13 | verkhnevilyuysk
# Processing Record 15 of Set 13 | nikolayevka
# Processing Record 16 of Set 13 | mareeba
# Processing Record 17 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 13 | orasac
# Processing Record 19 of Set 13 | maicao
# Processing Record 20 of Set 13 | sena madureira
# Processing Record 21 of Set 13 | kil
# Processing Record 22 of Set 13 | narsaq
# Processing Record 23 of Set 13 | bandarbeyla
# Processing Record 24 of Set 13 | bandiagara
# Processing Record 25 of Set 13 | port macquarie
# Processing Record 26 of Set 13 | suez
# Processing Record 27 of Set 13 | elko
# Processing Record 28 of Set 13 | barabai
# Processing Record 29 of Set 13 | huarmey
# Processing Record 30 of Set 13 | tura
# Processing Record 31 of Set 13 | arbagar
# Processing Record 32 of Set 13 | vieste
# Processing Record 33 of Set 13 | antofagasta
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | oum hadjer
# Processing Record 36 of Set 13 | collie
# Processing Record 37 of Set 13 | san quintin
# Processing Record 38 of Set 13 | vrangel
# Processing Record 39 of Set 13 | farkhor
# Processing Record 40 of Set 13 | rajaldesar
# Processing Record 41 of Set 13 | kisangani
# Processing Record 42 of Set 13 | portpatrick
# City not found. Skipping...
# Processing Record 43 of Set 13 | praia da vitoria
# Processing Record 44 of Set 13 | tres arroyos
# Processing Record 45 of Set 13 | coahuayana
# Processing Record 46 of Set 13 | guerrero negro
# Processing Record 47 of Set 13 | lieksa
# Processing Record 48 of Set 13 | wanning
# Processing Record 49 of Set 13 | matane
# Processing Record 50 of Set 13 | vila franca do campo
# Processing Record 1 of Set 14 | tabas
# Processing Record 2 of Set 14 | roma
# Processing Record 3 of Set 14 | huainan
# Processing Record 4 of Set 14 | monticello
# Processing Record 5 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 6 of Set 14 | lebanon
# Processing Record 7 of Set 14 | sabha
# Processing Record 8 of Set 14 | manzil bu ruqaybah
# City not found. Skipping...
# Processing Record 9 of Set 14 | innisfail
# Processing Record 10 of Set 14 | khairabad
# Processing Record 11 of Set 14 | chitrakonda
# Processing Record 12 of Set 14 | irbil
# Processing Record 13 of Set 14 | oranjemund
# Processing Record 14 of Set 14 | le pradet
# Processing Record 15 of Set 14 | broken hill
# Processing Record 16 of Set 14 | novonikolayevskiy
# Processing Record 17 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | olyka
# Processing Record 19 of Set 14 | poya
# Processing Record 20 of Set 14 | santa marta
# Processing Record 21 of Set 14 | shingu
# Processing Record 22 of Set 14 | emmett
# Processing Record 23 of Set 14 | sladkovo
# Processing Record 24 of Set 14 | boyolangu
# Processing Record 25 of Set 14 | watertown
# Processing Record 26 of Set 14 | mackenzie
# Processing Record 27 of Set 14 | spencer
# Processing Record 28 of Set 14 | tiarei
# Processing Record 29 of Set 14 | filadelfia
# Processing Record 30 of Set 14 | shitanjing
# Processing Record 31 of Set 14 | geraldton
# Processing Record 32 of Set 14 | tilichiki
# Processing Record 33 of Set 14 | axim
# Processing Record 34 of Set 14 | marsh harbour
# Processing Record 35 of Set 14 | korla
# Processing Record 36 of Set 14 | cravo norte
# Processing Record 37 of Set 14 | panacan
# Processing Record 38 of Set 14 | zhigalovo
# Processing Record 39 of Set 14 | bilibino
# Processing Record 40 of Set 14 | khani
# Processing Record 41 of Set 14 | puerto penasco
# Processing Record 42 of Set 14 | sobolevo
# Processing Record 43 of Set 14 | sayville
# Processing Record 44 of Set 14 | aswan
# Processing Record 45 of Set 14 | bastia
# Processing Record 46 of Set 14 | paka
# Processing Record 47 of Set 14 | syedove
# Processing Record 48 of Set 14 | lata
# Processing Record 49 of Set 14 | gigmoto
# Processing Record 50 of Set 14 | mokhsogollokh
# Processing Record 1 of Set 15 | pangai
# Processing Record 2 of Set 15 | calama
# Processing Record 3 of Set 15 | sasebo
# Processing Record 4 of Set 15 | adeje
# Processing Record 5 of Set 15 | adelaide
# Processing Record 6 of Set 15 | kemijarvi
# Processing Record 7 of Set 15 | georgiyevskoye
# Processing Record 8 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 9 of Set 15 | tessalit
# Processing Record 10 of Set 15 | zalantun
# Processing Record 11 of Set 15 | maidens
# Processing Record 12 of Set 15 | soyaux
# Processing Record 13 of Set 15 | pawai
# Processing Record 14 of Set 15 | shanhetun
# Processing Record 15 of Set 15 | tadine
# Processing Record 16 of Set 15 | kiunga
# Processing Record 17 of Set 15 | bandundu
# Processing Record 18 of Set 15 | kathmandu
# Processing Record 19 of Set 15 | amapa
# Processing Record 20 of Set 15 | copiapo
# Processing Record 21 of Set 15 | bubaque
# Processing Record 22 of Set 15 | saint simons
# Processing Record 23 of Set 15 | la ronge
# Processing Record 24 of Set 15 | taoudenni
# Processing Record 25 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 15 | ola
# Processing Record 27 of Set 15 | lahad datu
# Processing Record 28 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 15 | hangu
# Processing Record 30 of Set 15 | severodvinsk
# Processing Record 31 of Set 15 | tateyama
# Processing Record 32 of Set 15 | arica
# Processing Record 33 of Set 15 | banyo
# Processing Record 34 of Set 15 | eydhafushi
# Processing Record 35 of Set 15 | beisfjord
# Processing Record 36 of Set 15 | sawakin
# Processing Record 37 of Set 15 | bangkalan
# Processing Record 38 of Set 15 | waipawa
# Processing Record 39 of Set 15 | guaruja
# Processing Record 40 of Set 15 | vila velha
# Processing Record 41 of Set 15 | makinsk
# Processing Record 42 of Set 15 | las palmas
# Processing Record 43 of Set 15 | mega
# Processing Record 44 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 15 | chilliwack
# Processing Record 46 of Set 15 | misratah
# Processing Record 47 of Set 15 | barcelona
# Processing Record 48 of Set 15 | maturin
# Processing Record 49 of Set 15 | ekhabi
# Processing Record 50 of Set 15 | puerto ayacucho
# Processing Record 1 of Set 16 | kamenka
# Processing Record 2 of Set 16 | sturgis
# Processing Record 3 of Set 16 | cofradia
# Processing Record 4 of Set 16 | kahului
# Processing Record 5 of Set 16 | saquarema
# Processing Record 6 of Set 16 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 16 | kondinskoye
# Processing Record 8 of Set 16 | praya
# Processing Record 9 of Set 16 | najran
# Processing Record 10 of Set 16 | saveh
# Processing Record 11 of Set 16 | nantucket
# Processing Record 12 of Set 16 | tommot
# Processing Record 13 of Set 16 | mazatan
# Processing Record 14 of Set 16 | louisbourg
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Asau  46.4333   26.4000     40.12        84          95        5.68
# 1  Kangaatsiaq  68.3065  -53.4641     37.65        96         100        5.86
# 2    Busselton -33.6500  115.3333     53.67        74         100       12.82
# 3   Kaitangata -46.2817  169.8464     68.31        59          77        6.15
# 4    Cape Town -33.9258   18.4232     66.11        76           0       10.36
# 5    Ilulissat  69.2167  -51.1000     35.22       100         100        3.40
# 6      Ivanava  52.1451   25.5365     50.07        93          32        6.67
# 7    Kavaratti  10.5669   72.6420     81.43        63          37        8.10
# 8        Alofi -19.0595 -169.9187     77.13        76         100       17.58
# 9    Morondava -20.2833   44.2833     76.41        72          56        5.32
#
#   Country Current Description
# 0      RO     overcast clouds
# 1      GL          light rain
# 2      AU     overcast clouds
# 3      NZ       broken clouds
# 4      ZA           clear sky
# 5      GL          light snow
# 6      BY    scattered clouds
# 7      IN    scattered clouds
# 8      NU     overcast clouds
# 9      MG       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columns_reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[columns_reorder]

# Display sample data
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Asau      RO  46.4333   26.4000     40.12        84          95
# 1    Kangaatsiaq      GL  68.3065  -53.4641     37.65        96         100
# 2      Busselton      AU -33.6500  115.3333     53.67        74         100
# 3     Kaitangata      NZ -46.2817  169.8464     68.31        59          77
# 4      Cape Town      ZA -33.9258   18.4232     66.11        76           0
# ..           ...     ...      ...       ...       ...       ...         ...
# 700       Najran      SA  17.4924   44.1277     59.65        29           6
# 701        Saveh      IR  35.0213   50.3566     62.89        38           2
# 702    Nantucket      US  41.2835  -70.0995     51.91        79          40
# 703       Tommot      RU  58.9564  126.2925     15.62        91          86
# 704      Mazatan      MX  14.8667  -92.4500     82.47       100          75
#
#      Wind Speed Current Description
# 0          5.68     overcast clouds
# 1          5.86          light rain
# 2         12.82     overcast clouds
# 3          6.15       broken clouds
# 4         10.36           clear sky
# ..          ...                 ...
# 700        1.34           clear sky
# 701        3.11           clear sky
# 702       12.66    scattered clouds
# 703        1.48     overcast clouds
# 704        0.00       moderate rain
#
# [705 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
